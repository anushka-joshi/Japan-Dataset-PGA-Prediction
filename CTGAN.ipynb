# %%
import pandas as pd
from sdv.single_table import CTGANSynthesizer
from sdv.metadata import SingleTableMetadata
# ==========================================================
# File Paths
# ==========================================================
train_file = r"D:\Japan Dataset\Input Dataset\Train_tab_MAG_data_3_SEC.csv"
# ==========================================================
# Feature Columns
# ==========================================================
feature_cols = ["Tau_c","Tau_p",
    "RSSC Vel","CAV","CAD",
    "ID_2","IV_2","Arias intensity UD","Arias intensity NS","Arias intensity EW",
    "PGV UD 3 sec","PGD UD 3 sec","PGA UD 3 sec",
    "Station_Lat","Station_Lon","Focal depth",
    "Epicenter_Lat","V VS ACC","Vs30",
    "Epicenter_Lon","Total PGV UD","Total PGD UD","Total PGV NS","Total PGD NS","Total PGV EW","Total PGD EW",
    "Magnitude"]
# ==========================================================
# Load Dataset
# ==========================================================
df = pd.read_csv(train_file)[feature_cols]
print("Training samples :", len(df))
print("Features         :", len(df.columns))
# ==========================================================
# Build Metadata
# ==========================================================
metadata = SingleTableMetadata()
metadata.detect_from_dataframe(df)
# ==========================================================
# Train CTGAN
# ==========================================================
ctgan = CTGANSynthesizer(
    metadata=metadata,
    epochs=50,
    batch_size=50,
    embedding_dim=128,
    generator_dim=(256, 256),
    discriminator_dim=(256, 256),
    generator_lr=2e-4,
    discriminator_lr=2e-4,
    verbose=True,
    cuda=True)
ctgan.fit(df)
# Out:
# Training samples : 1955
# Features         : 27
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 44
#      30 # ==========================================================
#      31 # Train CTGAN
#      32 # ==========================================================
#      33 ctgan = CTGANSynthesizer(
#      34     metadata=metadata,
#      35     epochs=50,
#    (...)
#      42     verbose=True,
#      43     cuda=True)
# ---> 44 ctgan.fit(df)
#
# File D:\Miniconda\envs\tf\lib\site-packages\sdv\single_table\base.py:437, in BaseSynthesizer.fit(self, data)
#     435 self._random_state_set = False
#     436 processed_data = self._preprocess(data)
# --> 437 self.fit_processed_data(processed_data)
#
# File D:\Miniconda\envs\tf\lib\site-packages\sdv\single_table\base.py:420, in BaseSynthesizer.fit_processed_data(self, processed_data)
#     413 """Fit this model to the transformed data.
#     414
#     415 Args:
#     416     processed_data (pandas.DataFrame):
#     417         The transformed data used to fit the model to.
#     418 """
#     419 if not processed_data.empty:
# --> 420     self._fit(processed_data)
#     422 self._fitted = True
#     423 self._fitted_date = datetime.datetime.today().strftime('%Y-%m-%d')
#
# File D:\Miniconda\envs\tf\lib\site-packages\sdv\single_table\ctgan.py:189, in CTGANSynthesizer._fit(self, processed_data)
#     183 discrete_columns = detect_discrete_columns(
#     184     self.get_metadata(),
#     185     processed_data,
#     186     transformers
#     187 )
#     188 self._model = CTGAN(**self._model_kwargs)
# --> 189 self._model.fit(processed_data, discrete_columns=discrete_columns)
#
# File D:\Miniconda\envs\tf\lib\site-packages\ctgan\synthesizers\base.py:50, in random_state.<locals>.wrapper(self, *args, **kwargs)
#      48 def wrapper(self, *args, **kwargs):
#      49     if self.random_states is None:
# ---> 50         return function(self, *args, **kwargs)
#      52     else:
#      53         with set_random_states(self.random_states, self.set_random_state):
#
# File D:\Miniconda\envs\tf\lib\site-packages\ctgan\synthesizers\ctgan.py:305, in CTGAN.fit(self, train_data, discrete_columns, epochs)
#     298     warnings.warn(
#     299         ('`epochs` argument in `fit` method has been deprecated and will be removed '
#     300          'in a future version. Please pass `epochs` to the constructor instead'),
#     301         DeprecationWarning
#     302     )
#     304 self._transformer = DataTransformer()
# --> 305 self._transformer.fit(train_data, discrete_columns)
#     307 train_data = self._transformer.transform(train_data)
#     309 self._data_sampler = DataSampler(
#     310     train_data,
#     311     self._transformer.output_info_list,
#     312     self._log_frequency)
#
# File D:\Miniconda\envs\tf\lib\site-packages\ctgan\data_transformer.py:108, in DataTransformer.fit(self, raw_data, discrete_columns)
#     106     column_transform_info = self._fit_discrete(raw_data[[column_name]])
#     107 else:
# --> 108     column_transform_info = self._fit_continuous(raw_data[[column_name]])
#     110 self.output_info_list.append(column_transform_info.output_info)
#     111 self.output_dimensions += column_transform_info.output_dimensions
#
# File D:\Miniconda\envs\tf\lib\site-packages\ctgan\data_transformer.py:54, in DataTransformer._fit_continuous(self, data)
#      48 column_name = data.columns[0]
#      49 gm = ClusterBasedNormalizer(
#      50     missing_value_generation='from_column',
#      51     max_clusters=min(len(data), self._max_clusters),
#      52     weight_threshold=self._weight_threshold
#      53 )
# ---> 54 gm.fit(data, column_name)
#      55 num_components = sum(gm.valid_component_indicator)
#      57 return ColumnTransformInfo(
#      58     column_name=column_name, column_type='continuous', transform=gm,
#      59     output_info=[SpanInfo(1, 'tanh'), SpanInfo(num_components, 'softmax')],
#      60     output_dimensions=1 + num_components)
#
# File D:\Miniconda\envs\tf\lib\site-packages\rdt\transformers\base.py:55, in random_state.<locals>.wrapper(self, *args, **kwargs)
#      53 method_name = function.__name__
#      54 with set_random_states(self.random_states, method_name, self.set_random_state):
# ---> 55     return function(self, *args, **kwargs)
#
# File D:\Miniconda\envs\tf\lib\site-packages\rdt\transformers\base.py:390, in BaseTransformer.fit(self, data, column)
#     388 self._set_seed(data)
#     389 columns_data = self._get_columns_data(data, self.columns)
# --> 390 self._fit(columns_data)
#     391 self._build_output_columns(data)
#
# File D:\Miniconda\envs\tf\lib\site-packages\rdt\transformers\numerical.py:503, in ClusterBasedNormalizer._fit(self, data)
#     501 with warnings.catch_warnings():
#     502     warnings.simplefilter('ignore')
# --> 503     self._bgm_transformer.fit(data.reshape(-1, 1))
#     505 self.valid_component_indicator = self._bgm_transformer.weights_ > self.weight_threshold
#
# File D:\Miniconda\envs\tf\lib\site-packages\sklearn\mixture\_base.py:186, in BaseMixture.fit(self, X, y)
#     160 """Estimate model parameters with the EM algorithm.
#     161
#     162 The method fits the model ``n_init`` times and sets the parameters with
#    (...)
#     183     The fitted mixture.
#     184 """
#     185 # parameters are validated in fit_predict
# --> 186 self.fit_predict(X, y)
#     187 return self
#
# File D:\Miniconda\envs\tf\lib\site-packages\sklearn\mixture\_base.py:252, in BaseMixture.fit_predict(self, X, y)
#     249 for n_iter in range(1, self.max_iter + 1):
#     250     prev_lower_bound = lower_bound
# --> 252     log_prob_norm, log_resp = self._e_step(X)
#     253     self._m_step(X, log_resp)
#     254     lower_bound = self._compute_lower_bound(log_resp, log_prob_norm)
#
# File D:\Miniconda\envs\tf\lib\site-packages\sklearn\mixture\_base.py:309, in BaseMixture._e_step(self, X)
#     293 def _e_step(self, X):
#     294     """E step.
#     295
#     296     Parameters
#    (...)
#     307         the point of each sample in X.
#     308     """
# --> 309     log_prob_norm, log_resp = self._estimate_log_prob_resp(X)
#     310     return np.mean(log_prob_norm), log_resp
#
# File D:\Miniconda\envs\tf\lib\site-packages\sklearn\mixture\_base.py:529, in BaseMixture._estimate_log_prob_resp(self, X)
#     510 def _estimate_log_prob_resp(self, X):
#     511     """Estimate log probabilities and responsibilities for each sample.
#     512
#     513     Compute the log probabilities, weighted log probabilities per
#    (...)
#     527         logarithm of the responsibilities
#     528     """
# --> 529     weighted_log_prob = self._estimate_weighted_log_prob(X)
#     530     log_prob_norm = logsumexp(weighted_log_prob, axis=1)
#     531     with np.errstate(under="ignore"):
#     532         # ignore underflow
#
# File D:\Miniconda\envs\tf\lib\site-packages\sklearn\mixture\_base.py:482, in BaseMixture._estimate_weighted_log_prob(self, X)
#     471 def _estimate_weighted_log_prob(self, X):
#     472     """Estimate the weighted log-probabilities, log P(X | Z) + log weights.
#     473
#     474     Parameters
#    (...)
#     480     weighted_log_prob : array, shape (n_samples, n_component)
#     481     """
# --> 482     return self._estimate_log_prob(X) + self._estimate_log_weights()
#
# File D:\Miniconda\envs\tf\lib\site-packages\sklearn\mixture\_bayesian_mixture.py:761, in BayesianGaussianMixture._estimate_log_prob(self, X)
#     758 _, n_features = X.shape
#     759 # We remove `n_features * np.log(self.degrees_of_freedom_)` because
#     760 # the precision matrix is normalized
# --> 761 log_gauss = _estimate_log_gaussian_prob(
#     762     X, self.means_, self.precisions_cholesky_, self.covariance_type
#     763 ) - 0.5 * n_features * np.log(self.degrees_of_freedom_)
#     765 log_lambda = n_features * np.log(2.0) + np.sum(
#     766     digamma(
#     767         0.5
#    (...)
#     770     0,
#     771 )
#     773 return log_gauss + 0.5 * (log_lambda - n_features / self.mean_precision_)
#
# File D:\Miniconda\envs\tf\lib\site-packages\sklearn\mixture\_gaussian_mixture.py:454, in _estimate_log_gaussian_prob(X, means, precisions_chol, covariance_type)
#     447     log_prob = (
#     448         np.sum(means**2, 1) * precisions
#     449         - 2 * np.dot(X, means.T * precisions)
#     450         + np.outer(row_norms(X, squared=True), precisions)
#     451     )
#     452 # Since we are using the precision of the Cholesky decomposition,
#     453 # `- 0.5 * log_det_precision` becomes `+ log_det_precision_chol`
# --> 454 return -0.5 * (n_features * np.log(2 * np.pi) + log_prob) + log_det
#
# KeyboardInterrupt:

# %%
n_samples = 10000
batch_size = 1000
import warnings
# Suppress FutureWarnings
warnings.filterwarnings("ignore", category=FutureWarning)
synthetic_data = []
import numpy as np
import numpy as np
import pandas as pd
def generate(train_df,batch_size=256):
    X = ctgan.sample(num_rows=5000)
    X = pd.DataFrame(X, columns=feature_cols)
    X=X[X['Tau_c']>0]
    X=X[X['TP']>0]
    X=X[X['RSSC Vel']>0]
    X=X[X['CAV']>0]
    X=X[X['CAD']>0]
    X=X[X['ID_2']>0]
    X=X[X['IV_2']>0]
    X=X[X['Arias intensity UD']>0]
    X=X[X['Arias intensity NS']>0]
    X=X[X['Arias intensity EW']>0]
    X=X[X['PGD UD 3 sec']>0]
    X=X[X['PGV UD 3 sec']>0]
    X=X[X['PGA UD 3 sec']>0]
    X=X[X['Total PGD UD']>0]
    X=X[X['Total PGA UD']>0]
    X=X[X['Total PGV UD']>0]
    X=X[X['Total PGD EW']>0]
    X=X[X['Total PGA EW']>0]
    X=X[X['Total PGV EW']>0]
    X=X[X['Total PGD NS']>0]
    X=X[X['Total PGA NS']>0]
    X=X[X['Total PGV NS']>0]
    X=X[X['Focal depth']>0]
    X=X[X['Vs30']>0]
    min_st_lon=np.min(train_df['Station_Lon'])-1
    max_st_lon=np.max(train_df['Station_Lon'])+1
    min_st_lat=np.min(train_df['Station_Lat'])-1
    max_st_lat=np.max(train_df['Station_Lat'])+1
    X=X[X['Station_Lat']>=min_st_lat]
    X=X[X['Station_Lat']<=max_st_lat]
    X=X[X['Station_Lon']>=min_st_lon]
    X=X[X['Station_Lon']<=max_st_lon]
    return X
synthetic_data = []
train_file = r"D:\Japan Dataset\Input Dataset\India_train.csv"
feature_cols = ["Tau_c","Tau_p",
    "RSSC Vel","CAV","CAD",
    "ID_2","IV_2","Arias intensity UD","Arias intensity NS","Arias intensity EW",
    "PGV UD 3 sec","PGD UD 3 sec","PGA UD 3 sec",
    "Station_Lat","Station_Lon","Focal depth",
    "Epicenter_Lat","V VS ACC","Vs30",
    "Epicenter_Lon","Total PGV UD","Total PGD UD","Total PGV NS","Total PGD NS","Total PGV EW","Total PGD EW",
    "Magnitude"]
    # Read only required columns
train_df = pd.read_csv(train_file, usecols=feature_cols)
for i in range(0, n_samples, batch_size):
    current_batch = min(batch_size, n_samples - i)
    samples = generate(train_df,batch_size=current_batch)
    synthetic_data.append(samples)
synthetic_data = np.vstack(synthetic_data)
synthetic_df = pd.DataFrame(synthetic_data, columns=feature_cols)
output_file = r"D:\Japan Dataset\Output Dataset\Synthetic_India_Train_CTGAN.csv"
synthetic_df.to_csv(output_file, index=False)
print("\n=====================================")
print("Synthetic Dataset Generation Finished")
print("Shape :", synthetic_df.shape)
print("Saved :", output_file)
print("=====================================")
# Out:
# D:\Miniconda\envs\tf\lib\site-packages\pandas\core\arrays\masked.py:61: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 54
#      45 feature_cols = ["Tau_c","Tau_p",
#      46     "RSSC Vel","CAV","CAD",
#      47     "ID_2","IV_2","Arias intensity UD","Arias intensity NS","Arias intensity EW",
#    (...)
#      51     "Epicenter_Lon","Total PGV UD","Total PGD UD","Total PGV NS","Total PGD NS","Total PGV EW","Total PGD EW",
#      52     "Magnitude"]
#      53     # Read only required columns
# ---> 54 train_df = pd.read_csv(train_file, usecols=feature_cols)
#      55 for i in range(0, n_samples, batch_size):
#      56     current_batch = min(batch_size, n_samples - i)
#
# File D:\Miniconda\envs\tf\lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)
#    1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File D:\Miniconda\envs\tf\lib\site-packages\pandas\io\parsers\readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File D:\Miniconda\envs\tf\lib\site-packages\pandas\io\parsers\readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File D:\Miniconda\envs\tf\lib\site-packages\pandas\io\parsers\readers.py:1880, in TextFileReader._make_engine(self, f, engine)
#    1878     if "b" not in mode:
#    1879         mode += "b"
# -> 1880 self.handles = get_handle(
#    1881     f,
#    1882     mode,
#    1883     encoding=self.options.get("encoding", None),
#    1884     compression=self.options.get("compression", None),
#    1885     memory_map=self.options.get("memory_map", False),
#    1886     is_text=is_text,
#    1887     errors=self.options.get("encoding_errors", "strict"),
#    1888     storage_options=self.options.get("storage_options", None),
#    1889 )
#    1890 assert self.handles is not None
#    1891 f = self.handles.handle
#
# File D:\Miniconda\envs\tf\lib\site-packages\pandas\io\common.py:873, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     868 elif isinstance(handle, str):
#     869     # Check whether the filename is to be opened in binary mode.
#     870     # Binary mode does not support 'encoding' and 'newline'.
#     871     if ioargs.encoding and "b" not in ioargs.mode:
#     872         # Encoding
# --> 873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#     876             encoding=ioargs.encoding,
#     877             errors=errors,
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
#     882         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'D:\\Japan Dataset\\Input Dataset\\India_train.csv'
